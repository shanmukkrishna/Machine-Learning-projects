# %% [markdown]
# # https://www.kaggle.com/datasets/iammustafatz/diabetes-prediction-dataset

# %% [markdown]
# # <u> About this dataset</u>

# %% [markdown]
# ## The Diabetes prediction dataset is a collection of medical and demographic data from patients, along with their diabetes status (positive or negative). The data includes features such as age, gender, body mass index (BMI), hypertension, heart disease, smoking history, HbA1c level, and blood glucose level. This dataset can be used to build machine learning models to predict diabetes in patients based on their medical history and demographic information. This can be useful for healthcare professionals in identifying patients who may be at risk of developing diabetes and in developing personalized treatment plans. Additionally, the dataset can be used by researchers to explore the relationships between various medical and demographic factors and the likelihood of developing diabetes.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\Shanm\OneDrive\Desktop\diabetes_prediction_dataset.csv")

# %%
df
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# 1              6.6                   80         0
# 2              5.7                  158         0
# 3              5.0                  155         0
# 4              4.8                  155         0
# ...            ...                  ...       ...
# 99995          6.2                   90         0
# 99996          6.5                  100         0
# 99997          5.7                  155         0
# 99998          4.0                  100         0
# 99999          6.6                   90         0
#
# [100000 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 3854

# %%
df.drop_duplicates(keep='first',inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99994  Female  36.0             0              0         No Info  24.60
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# 1              6.6                   80         0
# 2              5.7                  158         0
# 3              5.0                  155         0
# 4              4.8                  155         0
# ...            ...                  ...       ...
# 99994          4.8                  145         0
# 99996          6.5                  100         0
# 99997          5.7                  155         0
# 99998          4.0                  100         0
# 99999          6.6                   90         0
#
# [96146 rows x 9 columns]

# %%
sns.countplot(data=df,x='heart_disease')
# Out:
# <AxesSubplot:xlabel='heart_disease', ylabel='count'>

# %%
sns.kdeplot(data=df,x='blood_glucose_level')
# Out:
# <AxesSubplot:xlabel='blood_glucose_level', ylabel='Density'>

# %%
plt.pie(df[['smoking_history']].value_counts(),labels=df[['smoking_history']].value_counts().index,autopct='%0.0f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x22848eb91f0>,
#   <matplotlib.patches.Wedge at 0x22848eb9a00>,
#   <matplotlib.patches.Wedge at 0x22848ec8160>,
#   <matplotlib.patches.Wedge at 0x22848ec8880>,
#   <matplotlib.patches.Wedge at 0x22848ec8fa0>,
#   <matplotlib.patches.Wedge at 0x22848ed6700>],
#  [Text(0.4753235911624408, 0.9920017558877813, "('never',)"),
#   Text(-1.0820458996556284, -0.19793097543952587, "('No Info',)"),
#   Text(-0.012579833490259899, -1.0999280648248582, "('former',)"),
#   Text(0.6146676746493359, -0.9122410041985497, "('current',)"),
#   Text(0.9810664025864919, -0.49750247609031995, "('not current',)"),
#   Text(1.090627212656216, -0.14329090345773302, "('ever',)")],
#  [Text(0.2592674133613313, 0.5410918668478806, '36%'),
#   Text(-0.5902068543576153, -0.10796235023974136, '34%'),
#   Text(-0.006861727358323581, -0.5999607626317408, '10%'),
#   Text(0.3352732770814559, -0.49758600229011796, '10%'),
#   Text(0.535127128683541, -0.2713649869583563, '7%'),
#   Text(0.594887570539754, -0.0781586746133089, '4%')])

# %%
df
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99994  Female  36.0             0              0         No Info  24.60
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# 1              6.6                   80         0
# 2              5.7                  158         0
# 3              5.0                  155         0
# 4              4.8                  155         0
# ...            ...                  ...       ...
# 99994          4.8                  145         0
# 99996          6.5                  100         0
# 99997          5.7                  155         0
# 99998          4.0                  100         0
# 99999          6.6                   90         0
#
# [96146 rows x 9 columns]

# %%
X=df[['gender','age','hypertension','heart_disease','smoking_history','bmi','HbA1c_level','blood_glucose_level']]

y=df['diabetes']

# %%
X.head()
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
#
#    HbA1c_level  blood_glucose_level
# 0          6.6                  140
# 1          6.6                   80
# 2          5.7                  158
# 3          5.0                  155
# 4          4.8                  155

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: diabetes, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=2)

# %%
X_train.shape
# Out:
# (72109, 8)

# %%
y_train.shape
# Out:
# (72109,)

# %%
X_train_cat=X_train[['gender','smoking_history']]

X_train_num=X_train[['age','hypertension','heart_disease','bmi','HbA1c_level','blood_glucose_level']]

# %%
X_train_cat.head()
# Out:
#        gender smoking_history
# 97149    Male         current
# 83757  Female         No Info
# 88927    Male         current
# 33573  Female         No Info
# 2825   Female         No Info

# %%
X_train_num.head()
# Out:
#         age  hypertension  heart_disease    bmi  HbA1c_level  \
# 97149  36.0             0              0  31.30          6.5
# 83757  46.0             0              0  37.75          6.0
# 88927  64.0             0              0  28.80          4.8
# 33573  65.0             0              0  27.32          4.0
# 2825    7.0             0              0  24.62          4.8
#
#        blood_glucose_level
# 97149                  126
# 83757                  155
# 88927                  159
# 33573                  158
# 2825                   159

# %%
from sklearn.preprocessing import OneHotEncoder

encoder=OneHotEncoder(drop='first',sparse=False)

X_train_cat_trans=pd.DataFrame(encoder.fit_transform(X_train_cat),
                              columns=encoder.get_feature_names_out(X_train_cat.columns),
                              index=X_train_cat.index)

X_train_cat_trans.head()
# Out:
# E:\Annaconda\lib\site-packages\sklearn\preprocessing\_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
#        gender_Male  gender_Other  smoking_history_current  \
# 97149          1.0           0.0                      1.0
# 83757          0.0           0.0                      0.0
# 88927          1.0           0.0                      1.0
# 33573          0.0           0.0                      0.0
# 2825           0.0           0.0                      0.0
#
#        smoking_history_ever  smoking_history_former  smoking_history_never  \
# 97149                   0.0                     0.0                    0.0
# 83757                   0.0                     0.0                    0.0
# 88927                   0.0                     0.0                    0.0
# 33573                   0.0                     0.0                    0.0
# 2825                    0.0                     0.0                    0.0
#
#        smoking_history_not current
# 97149                          0.0
# 83757                          0.0
# 88927                          0.0
# 33573                          0.0
# 2825                           0.0

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()

X_train_num_trans=pd.DataFrame(scaler.fit_transform(X_train_num),
                              columns=X_train_num.columns,
                              index=X_train_num.index)

X_train_num_trans.head()
# Out:
#             age  hypertension  heart_disease       bmi  HbA1c_level  \
# 97149 -0.260479     -0.290452      -0.207515  0.590896     0.903560
# 83757  0.184299     -0.290452      -0.207515  1.546214     0.439414
# 88927  0.984900     -0.290452      -0.207515  0.220618    -0.674537
# 33573  1.029378     -0.290452      -0.207515  0.001413    -1.417171
# 2825  -1.550336     -0.290452      -0.207515 -0.398487    -0.674537
#
#        blood_glucose_level
# 97149            -0.301317
# 83757             0.410085
# 88927             0.508210
# 33573             0.483679
# 2825              0.508210

# %%
X_train_transformed=pd.concat([X_train_num_trans,X_train_cat_trans],axis=1)

X_train_transformed.head()
# Out:
#             age  hypertension  heart_disease       bmi  HbA1c_level  \
# 97149 -0.260479     -0.290452      -0.207515  0.590896     0.903560
# 83757  0.184299     -0.290452      -0.207515  1.546214     0.439414
# 88927  0.984900     -0.290452      -0.207515  0.220618    -0.674537
# 33573  1.029378     -0.290452      -0.207515  0.001413    -1.417171
# 2825  -1.550336     -0.290452      -0.207515 -0.398487    -0.674537
#
#        blood_glucose_level  gender_Male  gender_Other  \
# 97149            -0.301317          1.0           0.0
# 83757             0.410085          0.0           0.0
# 88927             0.508210          1.0           0.0
# 33573             0.483679          0.0           0.0
# 2825              0.508210          0.0           0.0
#
#        smoking_history_current  smoking_history_ever  smoking_history_former  \
# 97149                      1.0                   0.0                     0.0
# 83757                      0.0                   0.0                     0.0
# 88927                      1.0                   0.0                     0.0
# 33573                      0.0                   0.0                     0.0
# 2825                       0.0                   0.0                     0.0
#
#        smoking_history_never  smoking_history_not current
# 97149                    0.0                          0.0
# 83757                    0.0                          0.0
# 88927                    0.0                          0.0
# 33573                    0.0                          0.0
# 2825                     0.0                          0.0

# %%
X_test_num=X_test[['age','hypertension','heart_disease','bmi','HbA1c_level','blood_glucose_level']]

X_test_cat=X_test[['gender','smoking_history']]

# %%
X_test_num.head()
# Out:
#         age  hypertension  heart_disease    bmi  HbA1c_level  \
# 35173  45.0             0              0  38.18          6.2
# 40184  71.0             0              0  28.17          5.7
# 78035  38.0             0              0  38.00          3.5
# 61878  23.0             0              0  37.48          5.8
# 88031  39.0             0              0  39.77          5.7
#
#        blood_glucose_level
# 35173                   85
# 40184                  159
# 78035                  140
# 61878                  158
# 88031                  159

# %%
X_test_cat.head()
# Out:
#        gender smoking_history
# 35173  Female            ever
# 40184  Female     not current
# 78035    Male           never
# 61878    Male         current
# 88031    Male           never

# %%
X_test_cat_trans=pd.DataFrame(encoder.transform(X_test_cat),
                              columns=encoder.get_feature_names_out(X_test_cat.columns),
                              index=X_test_cat.index)

X_test_cat_trans.head()
# Out:
#        gender_Male  gender_Other  smoking_history_current  \
# 35173          0.0           0.0                      0.0
# 40184          0.0           0.0                      0.0
# 78035          1.0           0.0                      0.0
# 61878          1.0           0.0                      1.0
# 88031          1.0           0.0                      0.0
#
#        smoking_history_ever  smoking_history_former  smoking_history_never  \
# 35173                   1.0                     0.0                    0.0
# 40184                   0.0                     0.0                    0.0
# 78035                   0.0                     0.0                    1.0
# 61878                   0.0                     0.0                    0.0
# 88031                   0.0                     0.0                    1.0
#
#        smoking_history_not current
# 35173                          0.0
# 40184                          1.0
# 78035                          0.0
# 61878                          0.0
# 88031                          0.0

# %%
X_test_num_trans=pd.DataFrame(scaler.transform(X_test_num),
                              columns=X_test_num.columns,
                              index=X_test_num.index)

X_test_num_trans.head()
# Out:
#             age  hypertension  heart_disease       bmi  HbA1c_level  \
# 35173  0.139822     -0.290452      -0.207515  1.609902     0.625072
# 40184  1.296245     -0.290452      -0.207515  0.127308     0.160926
# 78035 -0.171523     -0.290452      -0.207515  1.583242    -1.881317
# 61878 -0.838691     -0.290452      -0.207515  1.506224     0.253755
# 88031 -0.127045     -0.290452      -0.207515  1.845399     0.160926
#
#        blood_glucose_level
# 35173            -1.307091
# 40184             0.508210
# 78035             0.042119
# 61878             0.483679
# 88031             0.508210

# %%
X_test_transformed=pd.concat([X_test_num_trans,X_test_cat_trans],axis=1)

X_test_transformed.head()
# Out:
#             age  hypertension  heart_disease       bmi  HbA1c_level  \
# 35173  0.139822     -0.290452      -0.207515  1.609902     0.625072
# 40184  1.296245     -0.290452      -0.207515  0.127308     0.160926
# 78035 -0.171523     -0.290452      -0.207515  1.583242    -1.881317
# 61878 -0.838691     -0.290452      -0.207515  1.506224     0.253755
# 88031 -0.127045     -0.290452      -0.207515  1.845399     0.160926
#
#        blood_glucose_level  gender_Male  gender_Other  \
# 35173            -1.307091          0.0           0.0
# 40184             0.508210          0.0           0.0
# 78035             0.042119          1.0           0.0
# 61878             0.483679          1.0           0.0
# 88031             0.508210          1.0           0.0
#
#        smoking_history_current  smoking_history_ever  smoking_history_former  \
# 35173                      0.0                   1.0                     0.0
# 40184                      0.0                   0.0                     0.0
# 78035                      0.0                   0.0                     0.0
# 61878                      1.0                   0.0                     0.0
# 88031                      0.0                   0.0                     0.0
#
#        smoking_history_never  smoking_history_not current
# 35173                    0.0                          0.0
# 40184                    0.0                          1.0
# 78035                    1.0                          0.0
# 61878                    0.0                          0.0
# 88031                    1.0                          0.0

# %%
X_train_transformed.head()
# Out:
#             age  hypertension  heart_disease       bmi  HbA1c_level  \
# 97149 -0.260479     -0.290452      -0.207515  0.590896     0.903560
# 83757  0.184299     -0.290452      -0.207515  1.546214     0.439414
# 88927  0.984900     -0.290452      -0.207515  0.220618    -0.674537
# 33573  1.029378     -0.290452      -0.207515  0.001413    -1.417171
# 2825  -1.550336     -0.290452      -0.207515 -0.398487    -0.674537
#
#        blood_glucose_level  gender_Male  gender_Other  \
# 97149            -0.301317          1.0           0.0
# 83757             0.410085          0.0           0.0
# 88927             0.508210          1.0           0.0
# 33573             0.483679          0.0           0.0
# 2825              0.508210          0.0           0.0
#
#        smoking_history_current  smoking_history_ever  smoking_history_former  \
# 97149                      1.0                   0.0                     0.0
# 83757                      0.0                   0.0                     0.0
# 88927                      1.0                   0.0                     0.0
# 33573                      0.0                   0.0                     0.0
# 2825                       0.0                   0.0                     0.0
#
#        smoking_history_never  smoking_history_not current
# 97149                    0.0                          0.0
# 83757                    0.0                          0.0
# 88927                    0.0                          0.0
# 33573                    0.0                          0.0
# 2825                     0.0                          0.0

# %%
X_test_transformed.shape
# Out:
# (24037, 13)

# %%
X_train_transformed.shape
# Out:
# (72109, 13)

# %%
y_train.shape
# Out:
# (72109,)

# %%
from sklearn.linear_model import LogisticRegression

classifier=LogisticRegression()

classifier.fit(X_train_transformed,y_train)
# Out:
# LogisticRegression()

# %%
y_test_predict=classifier.predict(X_test_transformed)

# %%
from sklearn import metrics

metrics.accuracy_score(y_test,y_test_predict)
# Out:
# 0.9588967009194159

# %%
from sklearn.neighbors import KNeighborsClassifier

classifier=KNeighborsClassifier()

classifier.fit(X_train_transformed,y_train)

y_test_predict=classifier.predict(X_test_transformed)


metrics.accuracy_score(y_test,y_test_predict)
# Out:
# 0.9579398427424387

# %%
from sklearn.tree import DecisionTreeClassifier

classifier=DecisionTreeClassifier()

classifier.fit(X_train_transformed,y_train)

y_test_predict=classifier.predict(X_test_transformed)


metrics.accuracy_score(y_test,y_test_predict)
# Out:
# 0.9475392103839914
